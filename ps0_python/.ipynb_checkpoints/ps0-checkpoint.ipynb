# %% [markdown]
# ##Problem Sets 0
# For solving this problem set, I wrote a small library of helper functions called ps0. It contains some useful functions to help in better solving the problems. It's imported in the next cell below.
# ####1. Input Images
# #####a. Find two interesting images to use. They should be color, rectangular in shape (NOT square). Pick one that is wide and one tall.

# %%
# First, import some useful libraries.
import numpy
import cv2
import os
from ps0 import *
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
man_path = 'input/manback.jpeg' 
driver_path = 'input/img_99656.jpg'

driver = cv2.imread(driver_path)
man = cv2.imread(man_path)

# %% [markdown]
# ####2. Color Planes
# #####a. Swap the red and blue pixels of image 1
# #####Output: Store as ps0-2-a-1.png in the output folder

# %%
show_img(driver)

# %%
driver_bgr = driver[:,:,::-1]
man_bgr = man[:,:,::-1]

# %%
show_img(driver_bgr)

# %%
show_img(man_bgr)

# %%
cv2.imwrite('man_bgr.png', man_bgr)
cv2.imwrite('driver_bgr.png', driver_bgr)
# Out:
# True

# %% [markdown]
# #####b. Create a monochrome image (img1_red) by selecting the red channel of image 1.
# #####Output: ps0-2-b-1.png

# %%
driver_green = driver[:,:,1]
man_green = man[:,:,1]
cv2.imwrite('output/driver_green.png', driver_green)
cv2.imwrite('output/man_green.png', man_green)
# Out:
# True

# %%
plt.imshow(man_green, cmap='gray')

# %% [markdown]
# #####b. Create a monochrome image (img1_red) by selecting the red channel of image 1.
# #####Output: ps0-2-c-1.png

# %%
driver_red = driver[:,:,0]
man_red = man[:,:,0]
cv2.imwrite('output/driver_red.png', driver_red)
cv2.imwrite('output/man_red.png', man_red)
# Out:
# True

# %%
import matplotlib.image as mpimg
import numpy as np
fig = plt.figure()
a=fig.add_subplot(1,2,1)
img = mpimg.imread(driver_path)
lum_img = img[:,:,0]
imgplot = plt.imshow(lum_img)
a.set_title('Before')
plt.colorbar(ticks=[0.1,0.3,0.5,0.7], orientation ='horizontal')
a=fig.add_subplot(1,2,2)
imgplot = plt.imshow(lum_img)
#imgplot.set_clim(0.0,0.7)
a.set_title('After')
a.get_xaxis().set_ticks([])
#a = fig.add_subplot(2,3,1)
plt.colorbar(ticks=[0.1,0.3,0.5,0.7], orientation='horizontal')

# ---------------------------------------
# if needed inside the application logic, uncomment to show the images
plt.show()

# %%
cv2.imshow.__doc__
# Out:
# 'imshow(winname, mat) -> None'

# %%
def determine_fig_partition(num_imgs):
    """
    This function determines the partition of the
    figure area.
    """
    #print num_imgs
    if num_imgs == 1:
        num_plots_rows = 1
        num_plots_cols = 1
    elif num_imgs == 7:
        num_plots_rows = 2
        num_plots_cols = 4
    elif num_imgs % 2 == 0 and num_imgs >= 2:
        num_plots_rows = num_imgs/2
        num_plots_cols = 2
    elif num_imgs % 3 == 0 and num_imgs >= 3:
        num_plots_rows = num_imgs/3
        num_plots_cols = 3
    elif num_imgs % 5 == 0 and num_imgs >= 5:
        num_plots_rows = num_imgs/5
        num_plots_cols = 5
    return num_plots_rows, num_plots_cols
    
    
def show_multiple_images(images, convert_to_rgb = True):
    num_imgs = len(images)
    num_rows, num_cols = \
                determine_fig_partition(num_imgs)
    
    fig = plt.figure(figsize=(20,10))
    for i,img in enumerate(images, 1):
        a = fig.add_subplot(num_rows, num_cols, i)
        a.set_title(img)
        if convert_to_rgb == True:
            #cv2.cvtColor(images[img], cv2.COLOR_BGR2RGB)
            imgplot = plt.imshow(cv2.cvtColor(images[img],\
                                              cv2.COLOR_BGR2RGB))
        else:
            imgplot = plt.imshow(images[img])
        a.get_xaxis().set_ticks([])
        a.get_yaxis().set_ticks([])  
    plt.show()
        

show_multiple_images({'Driver': driver, 'Driver_1': driver_bgr})

# %%
print determine_fig_partition(7)
20 % 3 == 0
# Out:
# 7
# (2, 4)
# False

# %%
print enumerate.__doc__
# Out:
# enumerate(iterable[, start]) -> iterator for index, value of iterable
#
# Return an enumerate object.  iterable must be another object that supports
# iteration.  The enumerate object yields pairs containing a count (from
# start, which defaults to zero) and a value yielded by the iterable argument.
# enumerate is useful for obtaining an indexed list:
#     (0, seq[0]), (1, seq[1]), (2, seq[2]), ...
